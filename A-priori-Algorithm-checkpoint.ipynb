# %% [markdown]
# _______________________________________________________________________________________________________________________________
#
#                                            Name- Anubhav Shyam Goyal.
#
#                                            Roll no- 01.       Div- A.
#
#                                          Sub: Datamining and Warehousing
# ________________________________________________________________________________________________________________________________
#
# Title :
#
#     Apply a-priori algorithm to find frequently occurring items from given data and generate
#     strong association rules using support and confidence thresholds.
#     For Example: Market Basket Analysis.
#
# Software/Hardware Required:
#
#     jupyter notebook.
#
# Theory:
#
#     Apriori algorithm is given by R. Agrawal and R. Srikant in 1994 for finding frequent itemsets in a dataset for boolean     association rule. Name of the algorithm is Apriori because it uses prior knowledge of frequent itemset properties. We apply an  iterative approach or level-wise search where k-frequent itemsets are used to find k+1 itemsets.
#
#     To improve the efficiency of level-wise generation of frequent itemsets, an important property is used called Apriori property which helps by reducing the search space.
#
#
# Algorithm:
#
#     Step-1: Determine the support of itemsets in the transactional database, and select the minimum support and confidence.
#
#     Step-2: Take all supports in the transaction with higher support value than the minimum or selected support value.
#
#     Step-3: Find all the rules of these subsets that have higher confidence value than the threshold or minimum confidence.
#
#     Step-4: Sort the rules as the decreasing order of lift.
#
#
# Program:

# %%
dataset=[['Bread','Butter','Olive Oil','Veggies','Tomatoes','Broccoli'],
         ['Grapes','Butter','Olive Oil','Veggies','Tomatoes','Broccoli'],
         ['Bread','Oranges','Veggies','Tomatoes'],
         ['Bread','Olives','Fish','Veggies','Broccoli'],
         ['Fish','Butter','Butter','Veggies','Soy Sauce','Tomatoes']
         ]

# %%
dataset
# Out:
# [['Bread', 'Butter', 'Olive Oil', 'Veggies', 'Tomatoes', 'Broccoli'],
#  ['Grapes', 'Butter', 'Olive Oil', 'Veggies', 'Tomatoes', 'Broccoli'],
#  ['Bread', 'Oranges', 'Veggies', 'Tomatoes'],
#  ['Bread', 'Olives', 'Fish', 'Veggies', 'Broccoli'],
#  ['Fish', 'Butter', 'Butter', 'Veggies', 'Soy Sauce', 'Tomatoes']]

# %%
pip install mlxtend
# Out:
# Requirement already satisfied: mlxtend in c:\users\anubh\appdata\local\programs\python\python39\lib\site-packages (0.19.0)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: scipy>=1.2.1 in c:\users\anubh\appdata\local\programs\python\python39\lib\site-packages (from mlxtend) (1.7.0)
# Requirement already satisfied: pandas>=0.24.2 in c:\users\anubh\appdata\local\programs\python\python39\lib\site-packages (from mlxtend) (1.3.4)
# Requirement already satisfied: setuptools in c:\users\anubh\appdata\local\programs\python\python39\lib\site-packages (from mlxtend) (49.2.1)
# Requirement already satisfied: matplotlib>=3.0.0 in c:\users\anubh\appdata\local\programs\python\python39\lib\site-packages (from mlxtend) (3.4.3)
# Requirement already satisfied: joblib>=0.13.2 in c:\users\anubh\appdata\local\programs\python\python39\lib\site-packages (from mlxtend) (1.1.0)
# Requirement already satisfied: numpy>=1.16.2 in c:\users\anubh\appdata\local\programs\python\python39\lib\site-packages (from mlxtend) (1.19.3)
# Requirement already satisfied: scikit-learn>=0.20.3 in c:\users\anubh\appdata\local\programs\python\python39\lib\site-packages (from mlxtend) (1.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\anubh\appdata\local\programs\python\python39\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (2.8.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\anubh\appdata\local\programs\python\python39\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (0.10.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\anubh\appdata\local\programs\python\python39\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (1.3.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\anubh\appdata\local\programs\python\python39\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (8.3.1)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\anubh\appdata\local\programs\python\python39\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (2.4.7)
# Requirement already satisfied: pytz>=2017.3 in c:\users\anubh\appdata\local\programs\python\python39\lib\site-packages (from pandas>=0.24.2->mlxtend) (2021.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\anubh\appdata\local\programs\python\python39\lib\site-packages (from scikit-learn>=0.20.3->mlxtend) (3.0.0)
# Requirement already satisfied: six in c:\users\anubh\appdata\local\programs\python\python39\lib\site-packages (from cycler>=0.10->matplotlib>=3.0.0->mlxtend) (1.15.0)

# %%
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder

# %%
te=TransactionEncoder()
te_ary=te.fit(dataset).transform(dataset)

# %%
df=pd.DataFrame(te_ary,columns=te.columns_)
df
# Out:
#    Bread  Broccoli  Butter   Fish  Grapes  Olive Oil  Olives  Oranges  \
# 0   True      True    True  False   False       True   False    False
# 1  False      True    True  False    True       True   False    False
# 2   True     False   False  False   False      False   False     True
# 3   True      True   False   True   False      False    True    False
# 4  False     False    True   True   False      False   False    False
#
#    Soy Sauce  Tomatoes  Veggies
# 0      False      True     True
# 1      False      True     True
# 2      False      True     True
# 3      False     False     True
# 4       True      True     True

# %%
from mlxtend.frequent_patterns import apriori 
frequent_itemsets=apriori(df,min_support=0.6,use_colnames=True)
frequent_itemsets
# Out:
#     support                     itemsets
# 0       0.6                      (Bread)
# 1       0.6                   (Broccoli)
# 2       0.6                     (Butter)
# 3       0.8                   (Tomatoes)
# 4       1.0                    (Veggies)
# 5       0.6             (Veggies, Bread)
# 6       0.6          (Veggies, Broccoli)
# 7       0.6           (Tomatoes, Butter)
# 8       0.6            (Veggies, Butter)
# 9       0.8          (Veggies, Tomatoes)
# 10      0.6  (Veggies, Tomatoes, Butter)

# %%
from mlxtend.frequent_patterns import association_rules
res=association_rules(frequent_itemsets,metric='confidence',min_threshold=0.7)
res
# Out:
#             antecedents          consequents  antecedent support  \
# 0               (Bread)            (Veggies)                 0.6
# 1            (Broccoli)            (Veggies)                 0.6
# 2            (Tomatoes)             (Butter)                 0.8
# 3              (Butter)           (Tomatoes)                 0.6
# 4              (Butter)            (Veggies)                 0.6
# 5             (Veggies)           (Tomatoes)                 1.0
# 6            (Tomatoes)            (Veggies)                 0.8
# 7   (Veggies, Tomatoes)             (Butter)                 0.8
# 8     (Veggies, Butter)           (Tomatoes)                 0.6
# 9    (Tomatoes, Butter)            (Veggies)                 0.6
# 10           (Tomatoes)    (Veggies, Butter)                 0.8
# 11             (Butter)  (Veggies, Tomatoes)                 0.6
#
#     consequent support  support  confidence  lift  leverage  conviction
# 0                  1.0      0.6        1.00  1.00      0.00         inf
# 1                  1.0      0.6        1.00  1.00      0.00         inf
# 2                  0.6      0.6        0.75  1.25      0.12         1.6
# 3                  0.8      0.6        1.00  1.25      0.12         inf
# 4                  1.0      0.6        1.00  1.00      0.00         inf
# 5                  0.8      0.8        0.80  1.00      0.00         1.0
# 6                  1.0      0.8        1.00  1.00      0.00         inf
# 7                  0.6      0.6        0.75  1.25      0.12         1.6
# 8                  0.8      0.6        1.00  1.25      0.12         inf
# 9                  1.0      0.6        1.00  1.00      0.00         inf
# 10                 0.6      0.6        0.75  1.25      0.12         1.6
# 11                 0.8      0.6        1.00  1.25      0.12         inf

# %%
res1=res[['antecedents','consequents','support','confidence','lift']]
res1
# Out:
#             antecedents          consequents  support  confidence  lift
# 0               (Bread)            (Veggies)      0.6        1.00  1.00
# 1            (Broccoli)            (Veggies)      0.6        1.00  1.00
# 2            (Tomatoes)             (Butter)      0.6        0.75  1.25
# 3              (Butter)           (Tomatoes)      0.6        1.00  1.25
# 4              (Butter)            (Veggies)      0.6        1.00  1.00
# 5             (Veggies)           (Tomatoes)      0.8        0.80  1.00
# 6            (Tomatoes)            (Veggies)      0.8        1.00  1.00
# 7   (Veggies, Tomatoes)             (Butter)      0.6        0.75  1.25
# 8     (Veggies, Butter)           (Tomatoes)      0.6        1.00  1.25
# 9    (Tomatoes, Butter)            (Veggies)      0.6        1.00  1.00
# 10           (Tomatoes)    (Veggies, Butter)      0.6        0.75  1.25
# 11             (Butter)  (Veggies, Tomatoes)      0.6        1.00  1.25

# %%
res2=res1[res1['confidence']>=1]
res2
# Out:
#            antecedents          consequents  support  confidence  lift
# 0              (Bread)            (Veggies)      0.6         1.0  1.00
# 1           (Broccoli)            (Veggies)      0.6         1.0  1.00
# 3             (Butter)           (Tomatoes)      0.6         1.0  1.25
# 4             (Butter)            (Veggies)      0.6         1.0  1.00
# 6           (Tomatoes)            (Veggies)      0.8         1.0  1.00
# 8    (Veggies, Butter)           (Tomatoes)      0.6         1.0  1.25
# 9   (Tomatoes, Butter)            (Veggies)      0.6         1.0  1.00
# 11            (Butter)  (Veggies, Tomatoes)      0.6         1.0  1.25

# %% [markdown]
# Conclusion:
#
#     Apriori algorithm is an efficient algorithm that scans the database only once.It reduces the size of the itemsets in the database considerably providing a good performance.
#     Thus, data mining helps consumers and industries better in the decision-making process.
